# %% [markdown]
# #### NB: This file is for basic exploration (of the raw files) and is intended to enhance my understanding of the 7 csv files

# %%
import pandas as pd

# %% [markdown]
# ### This is a note to self for later

# %%
cnrsac = pd.read_csv("../data/2016_canton_nonperm_resperm_sex_age_canada.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %% [markdown]
# find and replace all accent characters

# %%
cnrsac["Canton"].unique()
# Out:
# array(['Switzerland', 'Zürich', 'Bern / Berne', 'Luzern', 'Uri', 'Schwyz',
#        'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Fribourg / Freiburg',
#        'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen',
#        'Appenzell Ausserrhoden', 'Appenzell Innerrhoden', 'St. Gallen',
#        'Graubünden / Grigioni / Grischun', 'Aargau', 'Thurgau', 'Ticino',
#        'Vaud', 'Valais / Wallis', 'Neuchâtel', 'Genève', 'Jura'], dtype=object)

# %%
cnrsac.Canton = cnrsac.Canton.replace({"Zürich": 'Zurich', "Graubünden / Grigioni / Grischun": "Graubunden / Grigioni / Grischun", 
                                           "Neuchâtel":"Neuchatel","Genève":"Geneve"})

# %%
cnrsac["Canton"].unique()
# Out:
# array(['Switzerland', 'Zurich', 'Bern / Berne', 'Luzern', 'Uri', 'Schwyz',
#        'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Fribourg / Freiburg',
#        'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen',
#        'Appenzell Ausserrhoden', 'Appenzell Innerrhoden', 'St. Gallen',
#        'Graubunden / Grigioni / Grischun', 'Aargau', 'Thurgau', 'Ticino',
#        'Vaud', 'Valais / Wallis', 'Neuchatel', 'Geneve', 'Jura'], dtype=object)

# %% [markdown]
# ### Begin examining each file

# %% [markdown]
# 2016_canton_perm_cit.csv

# %%
canton_perm_cit = pd.read_csv("../data/2016_canton_perm_cit.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_perm_cit.head()
# Out:
#    Year Canton (-) / District (>>) / Commune (......)  \
# 0  2016                                   Switzerland
# 1  2016                                      - Zürich
# 2  2016                           >> Bezirk Affoltern
# 3  2016                    ......0001 Aeugst am Albis
# 4  2016                 ......0002 Affoltern am Albis
#
#                  Population type  Citizenship - Total  Switzerland  Albania  \
# 0  Permanent resident population              8419550      6318404     1696
# 1  Permanent resident population              1487969      1092631      294
# 2  Permanent resident population                52904        43097        4
# 3  Permanent resident population                 1977         1718        0
# 4  Permanent resident population                11900         8586        2
#
#    Andorra  Belgium  Bulgaria  Denmark      ...        Samoa  Solomon Islands  \
# 0       29    13087      7836     4773      ...            7               11
# ...

# %%
canton_perm_cit.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2462 entries, 0 to 2461
# Columns: 205 entries, Year to No indication
# dtypes: int64(203), object(2)
# memory usage: 3.9+ MB

# %%
canton_perm_cit.Canada.describe()
# Out:
# count    2462.000000
# mean       10.997563
# std       153.213870
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max      6769.000000
# Name: Canada, dtype: float64

# %%
#canton_perm_cit[["Canton (-) / District (>>) / Commune (......)", "Population type","Canada"]]

# %% [markdown]
# 2016_canton_allpop_cit.csv

# %%
canton_allpop_cit = pd.read_csv("../data/2016_canton_allpop_cit.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_allpop_cit.head()
# Out:
#    Year Canton (-) / District (>>) / Commune (......)  \
# 0  2016                                   Switzerland
# 1  2016                                   Switzerland
# 2  2016                                      - Zürich
# 3  2016                                      - Zürich
# 4  2016                           >> Bezirk Affoltern
#
#                      Population type  Citizenship - Total  Switzerland  \
# 0      Permanent resident population              8419550      6318404
# 1  Non permanent resident population                77763            0
# 2      Permanent resident population              1487969      1092631
# 3  Non permanent resident population                12956            0
# 4      Permanent resident population                52904        43097
#
#    Albania  Andorra  Belgium  Bulgaria  Denmark      ...        Samoa  \
# 0     1696       29    13087      7836     4773      ...            7
# ...

# %% [markdown]
# 2016_canton_perm_resperm_sex_age_canada.csv

# %%
canton_perm_resperm_sex_age_canada = pd.read_csv("../data/2016_canton_perm_resperm_sex_age_canada.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_perm_resperm_sex_age_canada.head()
# Out:
#    Year       Canton                Population type          Residence permit  \
# 0  2016  Switzerland  Permanent resident population  Residence permit - Total
# 1  2016  Switzerland  Permanent resident population  Residence permit - Total
# 2  2016  Switzerland  Permanent resident population  Residence permit - Total
# 3  2016  Switzerland  Permanent resident population  Residence permit - Total
# 4  2016  Switzerland  Permanent resident population  Residence permit - Total
#
#            Sex          Age class  Canada
# 0  Sex - Total  Age class - Total    6769
# 1  Sex - Total          0-4 years     364
# 2  Sex - Total          5-9 years     355
# 3  Sex - Total        10-14 years     321
# 4  Sex - Total        15-19 years     240

# %% [markdown]
# 2016_canton_nonperm_birthpl_cit.csv

# %%
canton_nonperm_birthpl_cit = pd.read_csv("../data/2016_canton_perm_birthpl_cit.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_nonperm_birthpl_cit.head()
# Out:
#    Year Canton (-) / District (>>) / Commune (......)  \
# 0  2016                                   Switzerland
# 1  2016                                   Switzerland
# 2  2016                                   Switzerland
# 3  2016                                      - Zürich
# 4  2016                                      - Zürich
#
#                  Population type          Place of birth  Citizenship - Total  \
# 0  Permanent resident population  Place of birth - Total              8419550
# 1  Permanent resident population             Switzerland              5939518
# 2  Permanent resident population                  Abroad              2480032
# 3  Permanent resident population  Place of birth - Total              1487969
# 4  Permanent resident population             Switzerland               989230
#
#    Switzerland  Albania  Andorra  Belgium  Bulgaria      ...        Samoa  \
# 0      6318404     1696       29    13087      7836      ...            7
# ...

# %% [markdown]
# 2016_canton_nonperm_resperm_sex_age_canada.csv

# %%
canton_nonperm_resperm_sex_age_canada = pd.read_csv("../data/2016_canton_nonperm_resperm_sex_age_canada.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_nonperm_resperm_sex_age_canada.head()
# Out:
#    Year       Canton                    Population type  \
# 0  2016  Switzerland  Non permanent resident population
# 1  2016  Switzerland  Non permanent resident population
# 2  2016  Switzerland  Non permanent resident population
# 3  2016  Switzerland  Non permanent resident population
# 4  2016  Switzerland  Non permanent resident population
#
#            Residence permit          Sex          Age class  Canada
# 0  Residence permit - Total  Sex - Total  Age class - Total     497
# 1  Residence permit - Total  Sex - Total          0-4 years      17
# 2  Residence permit - Total  Sex - Total          5-9 years       6
# 3  Residence permit - Total  Sex - Total        10-14 years       4
# 4  Residence permit - Total  Sex - Total        15-19 years      74

# %% [markdown]
# 2016_canton_perm_birthpl_cit.csv

# %%
canton_perm_birthpl_cit = pd.read_csv("../data/2016_canton_perm_cit.csv", encoding="latin-1", sep=" ", low_memory=False, skiprows=1)

# %%
canton_perm_birthpl_cit.head()
# Out:
#    Year Canton (-) / District (>>) / Commune (......)  \
# 0  2016                                   Switzerland
# 1  2016                                      - Zürich
# 2  2016                           >> Bezirk Affoltern
# 3  2016                    ......0001 Aeugst am Albis
# 4  2016                 ......0002 Affoltern am Albis
#
#                  Population type  Citizenship - Total  Switzerland  Albania  \
# 0  Permanent resident population              8419550      6318404     1696
# 1  Permanent resident population              1487969      1092631      294
# 2  Permanent resident population                52904        43097        4
# 3  Permanent resident population                 1977         1718        0
# 4  Permanent resident population                11900         8586        2
#
#    Andorra  Belgium  Bulgaria  Denmark      ...        Samoa  Solomon Islands  \
# 0       29    13087      7836     4773      ...            7               11
# ...
