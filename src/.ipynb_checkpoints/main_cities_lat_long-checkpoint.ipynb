# %% [markdown]
# #### This script creates a dataframe of the latitude and longitudes of the 5 main cities evaluted in the hypothesis of this project: Zurich, Geneva, Basel, Lausanne, and Bern.

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("../data/clean_data/reduced_g1k15_canton_nonperm_canadians.csv", index_col=0)
# Out:
#       order    long     lat  group  id  KTNR  lat_coords  long_coords  \
# 0         1  692429  281173    0.1   0     1   47.680965     8.652293
# 1         2  692993  280860    0.1   0     1   47.678150     8.659697
# 2         3  693163  280421    0.1   0     1   47.674202     8.661929
# 3         4  693048  280201    0.1   0     1   47.672223     8.660419
# 4         5  693243  279410    0.1   0     1   47.665110     8.662979
# 5         6  693606  278826    0.1   0     1   47.659858     8.667745
# 6         7  693763  278851    0.1   0     1   47.660082     8.669806
# 7         8  693872  278450    0.1   0     1   47.656476     8.671237
# 8         9  694800  278137    0.1   0     1   47.653661     8.683420
# 9        10  695433  277578    0.1   0     1   47.648634     8.691731
# 10       11  695844  277859    0.1   0     1   47.651161     8.697126
# 11       12  696077  277577    0.1   0     1   47.648625     8.700185
# ...

# %%
canton_allpop_city = pd.read_csv("../data/clean_data/2016_canton_allpop_cit_cleaned.csv", index_col=0)

# %%
canton_allpop_city.loc[canton_allpop_city["Commune"] == "Zurich"]
# Out:
# Empty DataFrame
# ...
